# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as pt

# %%
data=pd.read_csv('Salary_Data.csv')
X=data.iloc[:,:-1].values
y=data.iloc[:,-1].values

# %%
print(X)
# Out:
# [[ 1.1]
#  [ 1.3]
#  [ 1.5]
#  [ 2. ]
#  [ 2.2]
#  [ 2.9]
#  [ 3. ]
#  [ 3.2]
#  [ 3.2]
#  [ 3.7]
#  [ 3.9]
#  [ 4. ]
#  [ 4. ]
#  [ 4.1]
#  [ 4.5]
#  [ 4.9]
#  [ 5.1]
#  [ 5.3]
#  [ 5.9]
#  [ 6. ]
#  [ 6.8]
#  [ 7.1]
#  [ 7.9]
#  [ 8.2]
#  [ 8.7]
#  [ 9. ]
#  [ 9.5]
#  [ 9.6]
#  [10.3]
#  [10.5]]

# %%
print(y)
# Out:
# [ 39343.  46205.  37731.  43525.  39891.  56642.  60150.  54445.  64445.
#   57189.  63218.  55794.  56957.  57081.  61111.  67938.  66029.  83088.
#   81363.  93940.  91738.  98273. 101302. 113812. 109431. 105582. 116969.
#  112635. 122391. 121872.]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=11)

# %%
print(X_test)
# Out:
# [[4.9]
#  [3.2]
#  [3. ]
#  [9.5]
#  [2. ]
#  [4. ]]

# %%
print(y_test)
# Out:
# [ 67938.  64445.  60150. 116969.  43525.  55794.]

# %%
print(X_train)
# Out:
# [[ 4.5]
#  [ 7.1]
#  [ 3.7]
#  [ 2.9]
#  [ 3.9]
#  [ 7.9]
#  [ 1.5]
#  [ 2.2]
#  [ 6.8]
#  [10.5]
#  [ 6. ]
#  [ 1.1]
#  [10.3]
#  [ 8.7]
#  [ 5.9]
#  [ 3.2]
#  [ 1.3]
#  [ 4. ]
#  [ 4.1]
#  [ 8.2]
#  [ 5.3]
#  [ 9.6]
#  [ 5.1]
#  [ 9. ]]

# %%
print(y_train)
# Out:
# [ 61111.  98273.  57189.  56642.  63218. 101302.  37731.  39891.  91738.
#  121872.  93940.  39343. 122391. 109431.  81363.  54445.  46205.  56957.
#   57081. 113812.  83088. 112635.  66029. 105582.]

# %%
from sklearn.linear_model import LinearRegression
reg=LinearRegression()
reg.fit(X_train,y_train)
pred=reg.predict(X_test)

# %%
pred
# Out:
# array([ 71949.71942864,  55791.24921078,  53890.25271456, 115672.63884167,
#         44385.27023347,  63395.23519566])

# %%
pt.scatter(X_train,y_train,color='red')
pt.plot(X_train,reg.predict(X_train),color='blue')
pt.title('Salary')
pt.xlabel('yrs of exp')
pt.ylabel('Salary_1')
pt.show()

# %%
pt.scatter(X_test,y_test,color='red')
pt.plot(X_train,reg.predict(X_train),color='blue')
pt.title('Salary')
pt.xlabel('yrs of exp')
pt.ylabel('Salary_1')
pt.show()

# %% [markdown]
# 1. LINEAR RELATIONSHIP

# %%
import matplotlib.pyplot as pt

fig , (ax1,ax2)=pt.subplots(ncols=2, figsize=(12,2.5))
ax1.scatter(data['YearsExperience'], data['Salary'])
ax1.set_title("Years of Experience vs Salary")
ax2.scatter(data['YearsExperience'], data['Salary'])
ax2.set_title("Years of Experience vs Salary")
pt.show()
